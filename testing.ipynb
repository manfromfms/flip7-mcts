# %%
from src.flip7_logic.Deck import Deck, STANDARD_DECK
from src.flip7_logic.Player import Player
from src.flip7_logic.State import State
from src.flip7_logic.Hand import Hand

h1 = Hand(cards=[])
p1 = Player(hand=h1, score=0, is_active=True)

h2 = Hand(cards=[])
p2 = Player(hand=h2, score=0, is_active=True)

h3 = Hand(cards=[])
p3 = Player(hand=h3, score=0, is_active=True)

game = State(STANDARD_DECK, [p1, p2, p3], Deck(cards=[]), turn=0)

game.generate_legal_moves()
# Out:
# [MoveDecision(player=Player(hand=<src.flip7_logic.Hand.Hand object at 0x7f672c069fd0>, score=0, is_active=True), hit=False),
#  MoveDecision(player=Player(hand=<src.flip7_logic.Hand.Hand object at 0x7f672c069fd0>, score=0, is_active=True), hit=True)]
